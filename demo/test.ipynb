# %%
# !nvidia-smi
# Out:
# Mon May 15 14:19:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Cloning the Repository

REPO_DIR = '/demo'
# %mkdir -p "$REPO_DIR"
# %cd "$REPO_DIR" 
# !git clone https://github.com/srijarkoroy/LinkSeg
# %cd "$REPO_DIR/LinkSeg"
# Out:
# /demo
# Cloning into 'LinkSeg'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 526 (delta 84), reused 83 (delta 60), pack-reused 404
# Receiving objects: 100% (526/526), 26.67 MiB | 40.46 MiB/s, done.
# Resolving deltas: 100% (214/214), done.
# /demo/LinkSeg

# %%
from inference import LinkNetSeg

# Initializing the LinkSeg Inference
lns = LinkNetSeg("misc/inputs/input1.png")

# Running inference
lns.inference(set_weight_dir = 'linknet.pth', path = 'misc/results/output.png', blend_path = 'misc/results/blend.png')
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1yBjHNblNJtGY49BIFg2mPsTDqAP5HYIk
# To: /demo/LinkSeg/weights/linknet.pth
# 100%|██████████| 124M/124M [00:00<00:00, 144MB/s]
# Download finished
# Segmented Output Generated! Please check in 'misc/results/'!
# FPS:  0.7230901606009247
# Accuracy:  0.9521

# %%
from PIL import Image

mask = Image.open("misc/results/output.png")
blend = Image.open("misc/results/blend.png")

mask.show()
print("\n\n\n")
blend.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=522x512 at 0x7F614359A350>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F614359A410>

# %%
# Uncomment and Run only before re-training
# %rm -r /demo
